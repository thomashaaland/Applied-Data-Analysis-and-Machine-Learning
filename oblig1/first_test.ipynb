# %%
# %%latex
# This is latex
# $$c = \sqrt{1+e}$$
# Out:
# This is latex
# $$c = \sqrt{1+e}$$

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

x = np.linspace(0,1,101)
y = x*x

plt.plot(x,y)
